# %%
# np.floor(metal * pow(factor, lv-1) * lv)

# %%
import pandas as pd
import numpy as np
import warnings


warnings.filterwarnings('ignore', 'PerformanceWarning')

# %%
data = pd.read_excel("cost_v9.xlsx", sheet_name=1)
data_academy = data.copy()
data = data[['Name EN', 'Type', 'Lifeform', 'metal base cost',
       'crystal base cost', 'deut base cost', 'energy base cost',
       'metal increase factor', 'crystal increase factor',
       'deut increase factor', 'energy increase factor', ]]


data_academy = data_academy[['Name EN', 'Lifeform', 'bonus 1 base value', 'bonus 1 increase factor']]


# on vire les na

data.fillna(0, inplace=True)
data_academy.fillna(0, inplace=True)

# Traduction

from google_trans_new import google_translator  
from tqdm import tqdm

translator = google_translator()

translations = {}

for word in tqdm(data['Name EN']):
    translations[word] = translator.translate(word, lang_tgt="fr")
 
# quelques modifs pour que ça corresponde aux jeux :

translations['Biosphere Farm'] = "Ferme biosphérique" 
translations['Neuro-Calibration Centre'] =  "Centre de neurocalibrage"
translations['Food Silo'] = "Réserve alimentaire"    
translations['Metropolis'] = "Métropolis"
translations['Fusion-Powered Production'] = "Extraction par fusion"
translations['Skyscraper\n'] = "Tour d'habitation"
translations['Intergalactic Envoys'] = "Ambassadeurs intergalactiques"
translations['High-Performance Extractors'] = "Extracteurs à haute performance"
translations['Fusion Drives'] = 'Moteurs à fusion'
translations['Sanctuary\n'] = "Refugium"
translations['Update Network'] = "Réseau d'actualisation"
translations['Quantum Computer Centre'] = "Centre d'informatique quantique"

translations
# Out:
# 100%|██████████| 120/120 [01:36<00:00,  1.24it/s]
# {'Residential Sector': 'Secteur résidentiel ',
#  'Biosphere Farm': 'Ferme biosphérique',
#  'Research Centre': 'Centre de recherche ',
#  'Academy of Sciences': 'Académie des sciences ',
#  'Neuro-Calibration Centre': 'Centre de neurocalibrage',
#  'High Energy Smelting': 'Fusion à haute énergie ',
#  'Food Silo': 'Réserve alimentaire',
#  'Fusion-Powered Production': 'Extraction par fusion',
#  'Skyscraper\n': "Tour d'habitation",
#  'Biotech Lab': 'Laboratoire de biotechnologie ',
#  'Metropolis': 'Métropolis',
#  'Planetary Shield': 'Bouclier planétaire ',
#  'Intergalactic Envoys': 'Ambassadeurs intergalactiques',
#  'High-Performance Extractors': 'Extracteurs à haute performance',
#  'Fusion Drives': 'Moteurs à fusion',
#  'Stealth Field Generator': 'Générateur de champs furtifs ',
#  'Orbital Den': 'Tanière orbitale ',
#  'Research AI': 'Recherche AI ',
#  'High-Performance Terraformer': 'Terraformateur haute performance ',
#  'Enhanced Production Technologies': 'Technologies de production améliorées ',
#  'Light Fighter Mk II': 'Light Fighter Mk II ',
#  'Cruiser Mk II': 'Cruiser MK II ',
#  'Improved Lab Technology': 'Amélioration de la technologie de laboratoire ',
#  'Plasma Terraformer': 'Terraformateur plasmatique ',
#  'Low-Temperature Drives': 'Drives à basse température ',
#  'Bomber Mk II': 'Bombardier mk et ',
#  'Destroyer Mk II': 'Destroyer MK II ',
#  'Battlecruiser Mk II': 'Battlecruiser Mk II ',
#  'Robot Assistants': 'Assistants de robot ',
#  'Supercomputer': 'Supercalculateur ',
#  'Meditation Enclave': 'Enclave de méditation ',
#  'Crystal Farm': 'Ferme cristalline ',
#  'Rune Technologium': 'Rune Technologium ',
#  'Rune Forge': 'Rune ',
#  'Oriktorium': 'Oriktorium ',
#  'Magma Forge': 'Magma Forge ',
#  'Disruption Chamber': 'Chambre de perturbation ',
#  'Megalith': 'Mégalithe ',
#  'Crystal Refinery': 'Raffinerie de cristal ',
#  'Deuterium Synthesiser': 'Synthétiseur de deutérium ',
#  'Mineral Research Centre': 'Centre de recherche minérale ',
#  'Advanced Recycling Plant': 'Plante de recyclage avancée ',
#  'Volcanic Batteries': 'Batteries volcaniques ',
#  'Acoustic Scanning': 'Balayage acoustique ',
#  'High Energy Pump Systems': 'Systèmes de pompe à grande énergie ',
#  'Cargo Hold Expansion (Civilian Ships)': 'Expansion de la maintenance (navires civils) ',
#  'Magma-Powered Production': 'Production de magma ',
#  'Geothermal Power Plants': 'Centrales géothermiques ',
#  'Depth Sounding': 'Sondage de profondeur ',
#  'Ion Crystal Enhancement (Heavy Fighter)': "Amélioration des cristaux d'ions (chasseur lourd) ",
#  'Improved Stellarator': 'Stellaire amélioré ',
#  'Hardened Diamond Drill Heads': 'Têtes de forage en diamant durcies ',
#  'Seismic Mining Technology': 'Technologie minière sismique ',
#  'Magma-Powered Pump Systems': 'Systèmes de pompe à propulsion du magma ',
#  'Ion Crystal Modules': 'Modules de cristal ion ',
#  'Optimised Silo Construction Method': 'Méthode de construction de silo optimisée ',
#  'Diamond Energy Transmitter': "Émetteur d'énergie en diamant ",
#  'Obsidian Shield Reinforcement': "Renforcement du bouclier d'obsidien ",
#  'Rune Shields': 'Boucliers runes ',
#  'Rock’tal Collector Enhancement': "Rock'tal Collector Amélioration ",
#  'Assembly Line': "Ligne d'assemblage ",
#  'Fusion Cell Factory': 'Usine de cellules de fusion ',
#  'Robotics Research Centre': 'Centre de recherche en robotique ',
#  'Update Network': "Réseau d'actualisation",
#  'Quantum Computer Centre': "Centre d'informatique quantique",
#  'Automatised Assembly Centre': "Centre d'assemblage automatisé ",
#  'High-Performance Transformer': 'Transformateur haute performance ',
#  'Microchip Assembly Line': 'Chaîne de montage de micropuces ',
#  'Production Assembly Hall': "Salle de l'assemblée de production ",
#  'High-Performance Synthesiser': 'Synthétiseur haute performance ',
#  'Chip Mass Production': 'Production de masse de puces ',
#  'Nano Repair Bots': 'Nano Repair Bots ',
#  'Catalyser Technology': 'Catalyser Technology ',
#  'Plasma Drive': 'Plasma ',
#  'Efficiency Module': "Module d'efficacité ",
#  'Depot AI': 'Dépôt que vous avez ',
#  'General Overhaul (Light Fighter)': 'Révision générale (combattant léger) ',
#  'Automated Transport Lines\n': 'Lignes de transport automatisées ',
#  'Improved Drone AI': "Amélioration de l'IA du drone ",
#  'Experimental Recycling Technology\n': 'Technologie de recyclage expérimental ',
#  'General Overhaul (Cruiser)': 'Révision générale (Cruiser) ',
#  'Slingshot Autopilot': 'Automatiquement automatique ',
#  'High-Temperature Superconductors': 'Superconducteurs à haute température ',
#  'General Overhaul (Battleship)': 'Révision générale (bataille) ',
#  'Artificial Swarm Intelligence': "Intelligence d'essaim artificielle ",
#  'General Overhaul (Battlecruiser)': 'Révision générale (Battlecruiser) ',
#  'General Overhaul (Bomber)': 'Révision générale (bombardier) ',
#  'General Overhaul (Destroyer)': 'Révision générale (destructeur) ',
#  'Experimental Weapons Technology': 'Technologie des armes expérimentales ',
#  'Mechan General Enhancement': 'Mechan General Amélioration ',
#  'Sanctuary\n': 'Refugium',
#  'Antimatter Condenser\n': "Condensateur d'anti-matière ",
#  'Vortex Chamber': 'Chambre vortex ',
#  'Halls of Realisation\n': 'Salles de réalisation ',
#  'Forum of Transcendence\n': 'Forum de transcendance ',
#  'Antimatter Convector\n': 'Convecteur antimatière ',
#  'Cloning Laboratory\n': 'Laboratoire de clonage ',
#  'Chrysalis Accelerator\n': 'Accélérateur de chrysalise ',
#  'Bio Modifier\n': 'Modificateur bio ',
#  'Psionic Modulator\n': 'Modulateur psionique ',
#  'Ship Manufacturing Hall\n': 'Hall de fabrication de navires ',
#  'Supra Refractor\n': 'Réfracteur ',
#  'Heat Recovery\n': 'Récupération de la chaleur ',
#  'Sulphide Process\n': 'Processus sulfuré ',
#  'Psionic Network\n': 'Réseau psionique ',
#  'Telekinetic Tractor Beam\n': 'Faisceau de tracteur télékinésique ',
#  'Enhanced Sensor Technology\n': 'Technologie de capteur améliorée ',
#  'Neuromodal Compressor\n': 'Compresseur neuromodal ',
#  'Neuro-Interface\n': 'Neuro-interface ',
#  'Interplanetary Analysis Network\n': "Réseau d'analyse interplanétaire ",
#  'Overclocking (Heavy Fighter)\n': 'Overclocking (combattant lourd) ',
#  'Telekinetic Drive\n': 'Lecteur télékinénétique ',
#  'Sixth Sense\n': 'Sixième sens ',
#  'Psychoharmoniser\n': 'Psychoharmoniser ',
#  'Efficient Swarm Intelligence\n': "Intelligence d'essaim efficace ",
#  'Overclocking (Large Cargo)\n': 'Overclocking (grande cargaison) ',
#  'Gravitation Sensors\n': 'Capteurs de gravitation ',
#  'Overclocking (Battleship)\n': 'Overclocking (cuirassé) ',
#  'Psionic Shield Matrix\n': 'Matrice de bouclier psionique ',
#  'Kaelesh Discoverer Enhancement': 'Kaelesh Discoverer Enhancement '}

# %%
data['Name FR'] = data['Name EN'].replace(translations)
data_academy['Name FR'] = data_academy['Name EN'].replace(translations)

# Pour les batiments N2
list = ['Académie des sciences', "Réseau d'actualisation", 'Rune', 'Salles de réalisation', 'Forum de transcendance', 'Centre de neurocalibrage', "Centre d'informatique quantique", "Oriktorium"]


data_academy = data_academy[data_academy['Name FR'].str.contains('|'.join(list))]

# On supprime un batiment qui ne doit pas être là
data_academy = data_academy[data_academy['Name EN'] != "Rune Technologium"]


data_academy
# Out:
#                      Name EN  Lifeform  bonus 1 base value  \
# 3        Academy of Sciences     Human          20000000.0
# 4   Neuro-Calibration Centre     Human         100000000.0
# 33                Rune Forge  Rock´tal          16000000.0
# 34                Oriktorium  Rock´tal          90000000.0
# 63            Update Network     Mecha          40000000.0
# 64   Quantum Computer Centre     Mecha         130000000.0
# 93    Halls of Realisation\n   Kaelesh          30000000.0
# 94  Forum of Transcendence\n   Kaelesh         100000000.0
#
#     bonus 1 increase factor                          Name FR
# 3                      1.10           Académie des sciences
# 4                      1.10         Centre de neurocalibrage
# 33                     1.14                            Rune
# 34                     1.10                      Oriktorium
# 63                     1.10           Réseau d'actualisation
# 64                     1.10  Centre d'informatique quantique
# 93                     1.10           Salles de réalisation
# 94                     1.10          Forum de transcendance

# %%
# Ajout jusqu'au level 30

# %%
for i in range(1,60):
    data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
    data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
    data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
    data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
    
    data_academy[f' Population min {i}'] = np.floor(data_academy['bonus 1 base value'] * pow(data_academy['bonus 1 increase factor'], i-1))/1000 
    # data_academy[f' Population min {i}'] = np.floor(data_academy['bonus 1 base value'] * pow(data_academy['bonus 1 increase factor'], i-1)*i)/1000
# Out:
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# ...
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'metal cost {i}'] = np.floor(data['metal base cost'] * pow(data['metal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'crystal cost {i}'] = np.floor(data['crystal base cost'] * pow(data['crystal increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'deut cost {i}'] = np.floor(data['deut base cost'] * pow(data['deut increase factor'], i-1)*i)/1000
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_8140\2468249099.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'energy cost {i}'] = np.floor(data['energy base cost'] * pow(data['energy increase factor'], i-1)*i)/1000

# %%
data_academy.drop(['Name EN', 'bonus 1 base value', 'bonus 1 increase factor'], axis=1, inplace=True)

# %%
with pd.ExcelWriter('data_cost.xlsx') as writer:  
    data.to_excel(writer, sheet_name='Sheet_name_1', index=False)
    data_academy.to_excel(writer, sheet_name='Sheet_name_2', index=False)
# data.to_excel("data_cost.xlsx", index=False)
